# %%
import pygsheets
import pandas as pd

api_limit_size = 25
apikey_pairs = [
    { "a@gmail.com": "apikey" },
    { "b@gmail.com": "apikey" },
    { "c@gmail.com": "apikey" }
]

apikeys = [ list(key.values())[0] for key in apikey_pairs ]

gc = pygsheets.authorize(service_file='./news-project.json')
sht = gc.open_by_key('google-sheet_key')

df = sht.worksheet_by_title('Transactions').get_as_df(start="A2")
tickers_list = df[df["Asset Class"] == "Stock"]["Asset Ticker"].unique().tolist()

splits_list = [ tickers_list[i : i+api_limit_size] for i in range(0, len(tickers_list), api_limit_size) ]

print("apikeys: ", apikeys)
print("splits_list: ", splits_list)


# --------------------
# Widget Dropdown Tool

import ipywidgets as widgets
from IPython.display import display, clear_output

ticker_group_list = splits_list[0]
group_index = 0
def on_dropdown_change(change):
    global ticker_group_list
    global group_index
    clear_output()
    display(hbox)
    selected_index = change.new
    try:
        ticker_group_list = splits_list[selected_index]
    except IndexError as e:
        print(f"IndexError: splits_list does not contain index {selected_index}")
    group_index = selected_index
    print(f"ticker_group_list: {ticker_group_list}")

dropdown = widgets.Dropdown(
    options=[('0', 0), ('1', 1), ('2', 2)],
    value=0,
    # description='splits_list[selected_index]',
)
dropdown.observe(on_dropdown_change, names='value')

dropdown.layout.height = '30px'
dropdown.layout.width = '50px'

label = widgets.Label('splits_list[selected_index]')
label.layout.width = '200px'
label.layout.font_size = '24px'
label.layout.align_items = 'center'
label.layout.justify_content = 'center'

hbox = widgets.HBox([label, dropdown])

display(hbox)

# %%
ticker_group_list
group_index
# Out:
# 1

# %%
import requests
import datetime

yesterday = datetime.datetime.now() - datetime.timedelta(days=1)
yesterday_str = yesterday.strftime('%Y%m%d')

formatted_news = ''

apikey = apikeys[0]
for ticker in ticker_group_list:
    
    url = f'https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers={ticker}&apikey={apikey}&time_from={yesterday_str}T0600'
    try:
        response = requests.get(url).json()

        try:
            news_list = response["feed"]
        except KeyError as e:
            print(f"No feed found for {ticker}. Response: {response}\n")
            continue
        
        number = 1
        formatted_news += f"\n****************************************\nStocker Ticker {ticker} 總共有{len(news_list)}則新聞\n"
        for news in news_list:
            title = news["title"]
            url = news["url"]
            time_published = news["time_published"]
            summary = news["summary"]
            ticker_formatted_news = f"""
--------------------------------------------------
NO. {number}
Stock Ticker: {ticker}
URL: {url}
Published Time: {time_published}\n
Title: {title}\n
Summary: {summary} \n\n
"""
            formatted_news += ticker_formatted_news
            number += 1
    except requests.RequestException as e:
        print(f"Request fail for ticker {ticker}. Error is: {e}")
    except ValueError as e:
        print(f"Error decoding JSON response for ticker {ticker}. Error: {e}")
    except Exception as e:
        print(f"Error occurred: {e}")
        
print("Formatted_news: \n", formatted_news)
# Out:
# No feed found for IWM. Response: {'Information': 'Invalid inputs. Please refer to the API documentation https://www.alphavantage.co/documentation#newsapi and try again.'}
#
# Formatted_news:
#
# ****************************************
# Stocker Ticker SNAP 總共有0則新聞
#
# ****************************************
# Stocker Ticker SNOW 總共有1則新聞
#
# --------------------------------------------------
# NO. 1
# Stock Ticker: SNOW
# URL: https://www.benzinga.com/insights/options/24/07/40048837/what-the-options-market-tells-us-about-snowflake
# Published Time: 20240730T191612
#
# Title: What the Options Market Tells Us About Snowflake - Snowflake  ( NYSE:SNOW )
#
# Summary: Whales with a lot of money to spend have taken a noticeably bearish stance on Snowflake. Looking at options history for Snowflake SNOW we detected 40 trades. If we consider the specifics of each trade, it is accurate to state that 30% of the investors opened trades with bullish expectations and ...
#
#
#
# ****************************************
# Stocker Ticker TSLA 總共有31則新聞
#
# --------------------------------------------------
# NO. 1
# Stock Ticker: TSLA
# URL: https://www.benzinga.com/news/24/07/40059424/tesla-senior-associate-for-regulatory-credits-leaves-after-realizing-890m-in-revenue-for-ev-giant-in
# Published Time: 20240731T072316
#
# Title: Tesla Senior Associate For Regulatory Credits Leaves After Realizing $890M In Revenue For EV Giant In Q2 - Tesla  ( NASDAQ:TSLA )
#
# Summary: Tesla Inc.'s TSLA senior associate for regulatory credits Ashlee Ramanathan took to Linkedin earlier this week to announce her departure from the company, days after the company reported revenue of $890 million from the sale of regulatory credits alone in the second quarter.
#
#
#
# --------------------------------------------------
# NO. 2
# Stock Ticker: TSLA
# URL: https://www.benzinga.com/news/24/07/40058998/rivian-follows-in-teslas-footsteps-reportedly-drops-key-fob-with-new-r1-deliveries
# Published Time: 20240731T063128
#
# Title: Rivian Follows In Tesla's Footsteps, Reportedly Drops Key Fob With New R1 Deliveries - Rivian Automotive  ( NASDAQ:RIVN )
#
# Summary: California-based EV maker Rivian Automotive RIVN has seemingly stopped providing new customers with a key fob. New Rivian customers now have to rely on either a key card or their mobile app to access, unlock, and drive their vehicles.
#
#
#
# --------------------------------------------------
# NO. 3
# Stock Ticker: TSLA
# URL: https://cointelegraph.com/news/magnificent-seven-stocks-shed-2-6-trillion-busy-earnings-week
# Published Time: 20240731T051458
#
# Title: 'Magnificent seven' stocks shed $2.6T in lead-up to busy earnings week
#
# Summary: The world's best-performing tech stocks have bled an average $125 billion market cap per day for the past 20 days while crypto market cap has risen 11%.
#
#
#
# --------------------------------------------------
# NO. 4
# Stock Ticker: TSLA
# URL: https://www.benzinga.com/news/24/07/40057398/elon-musk-might-be-sidelining-linkedin-to-promote-x-but-microsoft-ceo-satya-nadella-says-it-continue
# Published Time: 20240731T034036
#
# Title: Elon Musk Might Be Sidelining LinkedIn To Promote X, But Microsoft CEO Satya Nadella Says It Continues To See 'Record Engagement' - Microsoft  ( NASDAQ:MSFT )
#
# Summary: Tesla and SpaceX CEO Elon Musk has previously called LinkedIn "cringe," but Microsoft Corporation MSFT has reported a significant increase in engagement and growth on the platform.
#
#
#
# --------------------------------------------------
# NO. 5
# Stock Ticker: TSLA
# URL: https://www.scmp.com/business/markets/article/3272562/hsbc-leads-hong-kong-stocks-rebound-market-faces-risk-second-straight-monthly-loss
# Published Time: 20240731T024450
#
# Title: HSBC leads Hong Kong stocks rebound but market faces risk of monthly loss
#
# Summary: Hong Kong stocks posted early gains ahead of HSBC's earnings announcement but remain on track to report a second straight month of losses.
#
#
#
# --------------------------------------------------
# NO. 6
# Stock Ticker: TSLA
# URL: https://www.benzinga.com/markets/equities/24/07/40056947/nvidia-amd-microsoft-meta-tesla-why-these-5-stocks-are-on-investors-radars-today
# Published Time: 20240731T022427
#
# Title: Nvidia, AMD, Microsoft, Meta, Tesla: Why These 5 Stocks Are On Investors' Radars Today - Advanced Micro Devices  ( NASDAQ:AMD ) , Meta Platforms  ( NASDAQ:META )
#
# Summary: On Tuesday, major U.S. indices showed mixed results. The Dow Jones Industrial Average rose by 0.5% to close at 40,743.33, while the S&P 500 fell by a similar margin to 5,436.44. The Nasdaq dropped nearly 1.3%, ending the day at 17,147.42.
#
#
#
# --------------------------------------------------
# NO. 7
# Stock Ticker: TSLA
# URL: https://www.scmp.com/business/china-business/article/3272555/xpeng-expands-autonomous-driving-system-chinas-answer-teslas-fsd-all-cities
# Published Time: 20240731T011754
#
# Title: Xpeng expands autonomous driving to all mainland China cities
#
# Summary: Xpeng's X NGP software roll-out makes the company the first mainland carmaker to make a semi-autonomous driving system operational nationwide.
#
#
#
# --------------------------------------------------
# NO. 8
# Stock Ticker: TSLA
# URL: https://www.zacks.com/commentary/2312322/time-to-buy-stock-in-the-worlds-most-valuable-company-as-earnings-approach
# Published Time: 20240730T211100
#
# Title: Time to Buy Stock in the World's Most Valuable Company as Earnings Approach?
#
# Summary: As the world's most valuable company, markets will pay close attention to results for Apple's (AAPL) fiscal third quarter on Thursday, August 1.
#
#
#
# --------------------------------------------------
# NO. 9
# Stock Ticker: TSLA
# URL: https://www.benzinga.com/top-stories/24/07/40051173/sunrun-launches-nations-first-vehicle-to-home-power-plant-with-fords-help-to-revolutionize-the-grid
# Published Time: 20240730T202738
#
# Title: Sunrun Launches Nation's First Vehicle-To-Home Power Plant With Ford's Help To Revolutionize The Grid - Sunrun  ( NASDAQ:RUN )
#
# Summary: Clean energy company Sunrun RUN is behind the first vehicle-to-home power plant in the nation, using customer owned electric vehicles. What Happened: In an effort to alleviate demand on the electrical grid, Sunrun is utilizing F-150 Lightning electric pickup trucks owned by its energy customers ...
#
#
#
# --------------------------------------------------
# NO. 10
# Stock Ticker: TSLA
# URL: https://www.benzinga.com/pressreleases/24/07/r40049683/new-study-explores-potential-benefits-of-biophoton-generators-in-alzheimers-care
# Published Time: 20240730T200000
#
# Title: New Study Explores Potential Benefits of Biophoton Generators in Alzheimer's Care
#
# Summary: Philadelphia, PA July 30, 2024 -- ( PR.com ) -- Recent findings from a new First Institute of All Medicines ( FIAM ) clinical study suggest that biophoton generators improve cognitive functions and life quality in individuals with moderate or severe Alzheimer's disease.
#
#
#
# --------------------------------------------------
# NO. 11
# Stock Ticker: TSLA
# URL: https://www.benzinga.com/etfs/sector-etfs/24/07/40047835/dell-nvidia-amd-stocks-tumble-as-semiconductor-rally-stalls
# Published Time: 20240730T182515
#
# Title: Dell, Nvidia, AMD Stocks Tumble As Semiconductor Rally Stalls - Advanced Micro Devices  ( NASDAQ:AMD ) , Dell Technologies  ( NYSE:DELL )
#
# Summary: For the first half of 2024, computer and semiconductor names like Dell Technologies Inc DELL, NVIDIA Corp AMD and Advanced Micro Devices Inc AMD could no wrong. Hype around artificial intelligence and heightened demand for chips helped push share prices higher, creating what some experts have ...
#
#
#
# --------------------------------------------------
# NO. 12
# Stock Ticker: TSLA
# URL: https://www.benzinga.com/news/earnings/24/07/39988815/cooper-standard-set-for-significant-growth-amid-auto-industry-recovery
# Published Time: 20240730T175815
#
# Title: Cooper-Standard Set for Significant Growth Amid Auto Industry Recovery - Ford Motor  ( NYSE:F ) , Cooper-Standard Holdings  ( NYSE:CPS )
#
# Summary: Thesis: Cooper-Standard CPS is an auto parts supplier focused on sealing systems, fuel/brake delivery, and fluid transfer systems. The company was severely impacted by the downturn in new car volumes from 2018 to 2022 due to chip shortages, with revenues declining from $3.8 billion in 2017 to ...
#
#
#
# --------------------------------------------------
# NO. 13
# Stock Ticker: TSLA
# URL: https://www.benzinga.com/markets/latin-america/24/07/40045296/all-eyes-on-microsoft-the-fed-meeting-begins-venezuela-fraud
# Published Time: 20240730T163249
#
# Title: All Eyes On Microsoft, The Fed Meeting Begins, Venezuela Fraud - Apple  ( NASDAQ:AAPL )
#
# Summary: To gain an edge, this is what you need to know today. Please click here for an enlarged chart of Microsoft Corp MSFT. Projected Azure growth in the current quarter AI related capital expenditures and what will be the return on those expenditures
#
#
#
# --------------------------------------------------
# NO. 14
# Stock Ticker: TSLA
# URL: https://www.benzinga.com/trading-ideas/24/07/40044482/market-clubhouse-morning-memo-july-30th-2024-trade-strategy-for-spy-qqq-aapl-msft-nvda-googl-meta-a
# Published Time: 20240730T160124
#
# Title: Market Clubhouse Morning Memo - July 30th, 2024  ( Trade Strategy For SPY, QQQ, AAPL, MSFT, NVDA, GOOGL, META And TSLA )  - Invesco QQQ Trust, Series 1  ( NASDAQ:QQQ )
#
# Summary: Good Morning Traders! In today's Market Clubhouse Morning Memo, we will discuss SPY, QQQ, AAPL, MSFT, NVDA, GOOGL, META, and TSLA. Our proprietary formula, exclusive to Market Clubhouse, dictates these price levels. This dynamic equation takes into account price, volume, and options flow.
#
#
#
# --------------------------------------------------
# NO. 15
# Stock Ticker: TSLA
# URL: https://www.benzinga.com/insights/news/24/07/40043711/if-you-invested-1000-in-this-stock-5-years-ago-you-would-have-15-000-today
# Published Time: 20240730T153324
#
# Title: If You Invested $1000 In This Stock 5 Years Ago, You Would Have $15,000 Today - Tesla  ( NASDAQ:TSLA )
#
# Summary: Tesla TSLA has outperformed the market over the past 5 years by 57.9% on an annualized basis producing an average annual return of 71.72%. Currently, Tesla has a market capitalization of $725.89 billion.
#
#
#
# --------------------------------------------------
# NO. 16
# Stock Ticker: TSLA
# URL: https://www.zacks.com/stock/news/2312114/5-etfs-that-gained-maximum-investor-attention-last-week
# Published Time: 20240730T150000
#
# Title: 5 ETFs That Gained Maximum Investor Attention Last Week
#
# Summary: ETFs across various categories pulled in $22.1 billion in capital last week.
#
#
#
# --------------------------------------------------
# NO. 17
# Stock Ticker: TSLA
# URL: https://www.zacks.com/stock/news/2311945/can-these-5-auto-stocks-surpass-q2-earnings-predictions
# Published Time: 20240730T135600
#
# Title: Can These 5 Auto Stocks Surpass Q2 Earnings Predictions?
#
# Summary: The auto sector's second-quarter earnings are projected to decline 10.4% year over year. Let's examine how OSK, CVNA, BWA, AN and PAG are positioned ahead of their quarterly releases.
#
#
#
# --------------------------------------------------
# NO. 18
# Stock Ticker: TSLA
# URL: https://decrypt.co/242320/elon-musk-says-theres-some-merit-in-bitcoin-and-he-has-a-soft-spot-for-dogecoin
# Published Time: 20240730T125230
#
# Title: Elon Musk Says There's 'Some Merit' in Bitcoin and He Has a 'Soft Spot' for Dogecoin
#
# Summary: The Tesla CEO said has a "soft spot" for Dogecoin because "I like dogs and memes," he said in a recent interview.
#
#
#
# --------------------------------------------------
# NO. 19
# Stock Ticker: TSLA
# URL: https://www.zacks.com/stock/news/2311609/best-inverseleveraged-etfs-of-last-week
# Published Time: 20240730T122600
#
# Title: Best Inverse/Leveraged ETFs of Last Week
#
# Summary: Wall Street offered a mixed performance last week.
#
#
#
# --------------------------------------------------
# NO. 20
# Stock Ticker: TSLA
# URL: https://www.zacks.com/stock/news/2311571/tesla-etfs-time-to-buy-or-hold-post-lackluster-q2-earnings
# Published Time: 20240730T120000
#
# Title: Tesla ETFs: Time to Buy or Hold Post Lackluster Q2 Earnings?
#
# Summary: Tesla (TSLA) shares gained on Monday after Morgan Stanley named Tesla as "top pick" in the US automotive industry, replacing Ford. Buy or Hold Tesla-heavy ETFs?
#
#
#
# --------------------------------------------------
# NO. 21
# Stock Ticker: TSLA
# URL: https://www.benzinga.com/news/24/07/40034466/elon-musk-jokes-about-telegram-ceos-claim-of-100-biological-children-says-genghis-khan-would-have-sc
# Published Time: 20240730T115227
#
# Title: Elon Musk Jokes About Telegram CEO's Claim Of 100 Biological Children, Says Genghis Khan Would Have Scoffed At Pavel Durov: 'Rookie Numbers LMAO'
#
# Summary: Tesla CEO Elon Musk humorously responded to Telegram CEO Pavel Durov's claim of having over 100 biological children, comparing him with Mongol empire founder Genghis Khan. What Happened: Durov recently claimed to have fathered more than 100 biological children in 12 different countries through ...
#
#
#
# --------------------------------------------------
# NO. 22
# Stock Ticker: TSLA
# URL: https://www.benzinga.com/news/24/07/40034205/transportation-secretary-pete-buttigieg-says-china-understands-strategic-value-of-dominating-market
# Published Time: 20240730T113954
#
# Title: Transportation Secretary Pete Buttigieg Says China Understands 'Strategic Value' Of Dominating Market, Terms Ideological Differences On EVs 'Frustrating:' 'There Should Be Nothing Ideological About That…'
#
# Summary: The U.S. cannot outcompete China by ignoring the EV revolution, according to Transportation Secretary Pete Buttigieg.
#
#
#
# --------------------------------------------------
# NO. 23
# Stock Ticker: TSLA
# URL: https://www.business-standard.com/industry/auto/maharashtra-tamil-nadu-lead-the-race-for-tesla-s-manufacturing-unit-124073001023_1.html
# Published Time: 20240730T113615
#
# Title: Tesla manufacturing unit India: Maharashtra, Tamil Nadu lead the race for Tesla's manufacturing unit
#
# Summary: Gujarat also in list, if govt rolls out sops. in talks to rope in local partners ...
#
#
#
# --------------------------------------------------
# NO. 24
# Stock Ticker: TSLA
# URL: https://www.fool.com/investing/2024/07/30/1-magnificent-ev-stock-to-buy-and-hold-forever/
# Published Time: 20240730T110000
#
# Title: 1 Magnificent EV Stock Down 84% to Buy and Hold Forever
#
# Summary: If you're looking to bet on EVs, this growth stock is for you.
#
#
#
# --------------------------------------------------
# NO. 25
# Stock Ticker: TSLA
# URL: https://www.benzinga.com/news/24/07/40031872/tesla-recalls-over-1-8m-vehicles-over-concerns-of-unlatched-hood-opening-when-driving
# Published Time: 20240730T100810
#
# Title: Tesla Recalls Over 1.8M Vehicles Over Concerns Of Unlatched Hood Opening When Driving - Tesla  ( NASDAQ:TSLA )
#
# Summary: EV giant Tesla Inc TSLA is recalling over 1.8 million vehicles in the U.S. over concerns that an unlatched hood can fully open when driving, obstructing the driver's view and increasing risks of a crash. What Happened: The recall population includes different model years of Model 3, Model S, ...
#
#
#
# --------------------------------------------------
# NO. 26
# Stock Ticker: TSLA
# URL: https://www.benzinga.com/markets/equities/24/07/40031326/how-a-phone-call-with-vanguard-founder-jack-bogle-transformed-bob-pisanis-perspective-and-revolu
# Published Time: 20240730T095333
#
# Title: How A Phone Call With Vanguard Founder Jack Bogle Transformed Bob Pisani's Perspective And Revolutionized Investing
#
# Summary: Bob Pisani, a senior markets correspondent, shared how a phone call with Jack Bogle, the founder of Vanguard, transformed his perspective on investing and ultimately changed the investment world. What Happened: In 1997, Pisani, who was just starting as the on-air stocks editor for CNBC, had a ...
#
#
#
# --------------------------------------------------
# NO. 27
# Stock Ticker: TSLA
# URL: https://www.benzinga.com/news/24/07/40031325/former-tesla-exec-says-biden-administrations-treatment-of-ev-giant-was-pretty-fair-despite-musks-all
# Published Time: 20240730T095324
#
# Title: Former Tesla Exec Says Biden Administration's Treatment Of EV Giant Was 'Pretty Fair' Despite Musk's Allegations That It Would Rather The Company 'Be Dead Than Not Unionized' - Tesla  ( NASDAQ:TSLA )
#
# Summary: The Biden administration treated EV giant Tesla Inc. TSLA fairly on certain issues despite "surface-level disappointment" between the President and company CEO Elon Musk, according to former company executive Rohan Patel.
#
#
#
# --------------------------------------------------
# NO. 28
# Stock Ticker: TSLA
# URL: https://www.fool.com/investing/2024/07/30/nvidia-alphabet-microsoft-month-safer-in-ai-stocks/
# Published Time: 20240730T091500
#
# Title: Nvidia, Alphabet, and Microsoft Are Sinking This Month. Here's a Safer Way to Invest in Artificial Intelligence  ( AI )  Stocks.
#
# Summary: Investors won't have to pick winners and losers in the artificial intelligence (AI) race with this simple strategy.
#
#
#
# --------------------------------------------------
# NO. 29
# Stock Ticker: TSLA
# URL: https://www.benzinga.com/analyst-ratings/analyst-color/24/07/40030402/tesla-replaces-ford-as-morgan-stanleys-top-pick-as-brokerage-sees-potential-in-ev-g
# Published Time: 20240730T083729
#
# Title: Tesla Replaces Ford As Morgan Stanley's 'Top Pick' As Brokerage Sees Potential In EV Giant's Energy And Service Segments - Tesla  ( NASDAQ:TSLA ) , Ford Motor  ( NYSE:F )
#
# Summary: EV giant Tesla Inc TSLA has replaced Ford Motor Co F as Morgan Stanley's "Top pick" in the U.S. auto industry. Analyst Ratings: Morgan Stanley has a price target of $310 for Tesla and $16 for Ford. This is an upside of nearly 34% from Tesla's closing price on Monday, and nearly 45% for Ford, ...
#
#
#
# --------------------------------------------------
# NO. 30
# Stock Ticker: TSLA
# URL: https://www.benzinga.com/news/earnings/24/07/40029782/us-stocks-close-mixed-ahead-of-big-earnings-fed-decision-investor-optimism-improves-further
# Published Time: 20240730T074544
#
# Title: US Stocks Close Mixed Ahead Of Big Earnings, Fed Decision: Investor Optimism Improves Further - Tesla  ( NASDAQ:TSLA )
#
# Summary: The CNN Money Fear and Greed index showed some improvement in the overall market sentiment, with the index remaining in the "Neutral" zone on Monday. U.S. stocks closed mixed on Monday, ahead of earnings results from major companies and the Federal Reserve's policy decision this week.
#
#
#
# --------------------------------------------------
# NO. 31
# Stock Ticker: TSLA
# URL: https://www.benzinga.com/news/24/07/40028740/tesla-ceo-elon-musk-turns-down-possibility-of-model-s-plaid-plus-variant-upcoming-roadster-set-to-fi
# Published Time: 20240730T061344
#
# Title: Tesla CEO Elon Musk Turns Down Possibility Of Model S Plaid Plus Variant, Upcoming Roadster Set To Fill That Gap Instead - Tesla  ( NASDAQ:TSLA )
#
# Summary: Tesla Inc TSLA CEO Elon Musk on Monday denied any future possibility of the company making a Plaid+ version of the Model S sedan. What Happened: The void of a Plaid+ version of the Model S will be filled by the Roadster, Musk said in a reply on social media platform X.
#
#
#
# ****************************************
# Stocker Ticker U 總共有1則新聞
#
# --------------------------------------------------
# NO. 1
# Stock Ticker: U
# URL: https://www.zacks.com/stock/news/2312387/unity-software-inc-u-dips-more-than-broader-market-what-you-should-know
# Published Time: 20240730T214522
#
# Title: Unity Software Inc.  ( U )  Dips More Than Broader Market: What You Should Know
#
# Summary: Unity Software Inc. (U) closed the most recent trading day at $16.20, moving -0.95% from the previous trading session.
#
#
#
# ****************************************
# Stocker Ticker WOLF 總共有0則新聞
#
# ****************************************
# Stocker Ticker ACN 總共有1則新聞
#
# --------------------------------------------------
# NO. 1
# Stock Ticker: ACN
# URL: https://www.fool.com/earnings/call-transcripts/2024/07/30/microsoft-msft-q4-2024-earnings-call-transcript/
# Published Time: 20240731T024514
#
# Title: Microsoft  ( MSFT )  Q4 2024 Earnings Call Transcript
#
# Summary: MSFT earnings call for the period ending June 30, 2024.
#
#
#
# ****************************************
# Stocker Ticker GOOG 總共有50則新聞
#
# --------------------------------------------------
# NO. 1
# Stock Ticker: GOOG
# URL: https://www.benzinga.com/news/24/07/40059421/mark-zuckerbergs-meta-blames-hallucination-for-ai-assistant-incorrectly-denying-trump-assassination
# Published Time: 20240731T072252
#
# Title: Mark Zuckerberg's Meta Blames Hallucination For AI Assistant Incorrectly Denying Trump Assassination Attempt - But What About Google? - Alphabet  ( NASDAQ:GOOG ) , Alphabet  ( NASDAQ:GOOGL )
#
# Summary: Meta Platforms Inc. META has been criticized for its AI assistant's false denial of an attempted assassination on former President Donald Trump. However, now the company has finally addressed the issue.
#
#
#
# --------------------------------------------------
# NO. 2
# Stock Ticker: GOOG
# URL: https://consent.google.com/m
# Published Time: 20240731T065318
#
# Title: Before you continue
#
# Summary: LIVE news: Delhi govt to bring law to regulate coaching centres, says minister Atishi Business Standard ...
#
#
#
# --------------------------------------------------
# NO. 3
# Stock Ticker: GOOG
# URL: https://www.business-standard.com/technology/tech-news/nothing-phone-2a-plus-launch-at-2-30-pm-where-to-watch-and-what-to-expect-124073100404_1.html
# Published Time: 20240731T060716
#
# Title: Nothing Phone 2a Plus launch at 2:30 pm: Where to watch and what to expect
#
# Summary: Nothing has confirmed that the Phone 2a Plus will be powered by MediaTek Dimesity 7350 Pro and sport a 50MP camera sensor on the front and a dual 50MP camera set-up on the rear ...
#
#
#
# --------------------------------------------------
# NO. 4
# Stock Ticker: GOOG
# URL: https://www.business-standard.com/finance/personal-finance/key-financial-rules-will-change-from-august-1-what-you-should-do-124073100402_1.html
# Published Time: 20240731T060200
#
# Title: Key financial rules will change from August 1: What you should do
#
# Summary: Significant updates, include new Google Maps charges and revised HDFC Bank credit card regulations ...
#
#
#
# --------------------------------------------------
# NO. 5
# Stock Ticker: GOOG
# URL: https://consent.google.com/m
# Published Time: 20240731T060100
#
# Title: Before you continue
#
# Summary: Yen choppy after BoJ rate hike Business Standard ...
#
#
#
# --------------------------------------------------
# NO. 6
# Stock Ticker: GOOG
# URL: https://www.globenewswire.com/news-release/2024/07/31/2921577/0/en/Wolters-Kluwer-2024-Half-Year-Report.html
# Published Time: 20240731T060100
#
# Title: Wolters Kluwer 2024 Half-Year Report
#
# Summary: Alphen aan den Rijn, July 31, 2024 - Wolters Kluwer, a global leader in professional information, software solutions and services, today releases its half-year 2024 results. • Revenues €2,891 million, up 6% in constant currencies and up 6% organically. • Diluted adjusted EPS €2.36, up 9% overall ...
#
#
#
# --------------------------------------------------
# NO. 7
# Stock Ticker: GOOG
# URL: https://consent.google.com/m
# Published Time: 20240731T054619
#
# Title: Before you continue
#
# Summary: Jute sector highlights key issues at standing advisory committee meeting Business Standard ...
#
#
#
# --------------------------------------------------
# NO. 8
# Stock Ticker: GOOG
# URL: https://consent.google.com/m
# Published Time: 20240731T051700
#
# Title: Before you continue
#
# Summary: US markets end mixed. FOMC eyed Business Standard ...
#
#
#
# --------------------------------------------------
# NO. 9
# Stock Ticker: GOOG
# URL: https://consent.google.com/m
# Published Time: 20240731T051540
#
# Title: Before you continue
#
# Summary: Venezuelans protest as observers say presidential vote undemocratic Business Standard ...
#
#
#
# --------------------------------------------------
# NO. 10
# Stock Ticker: GOOG
# URL: https://cointelegraph.com/news/magnificent-seven-stocks-shed-2-6-trillion-busy-earnings-week
# Published Time: 20240731T051458
#
# Title: 'Magnificent seven' stocks shed $2.6T in lead-up to busy earnings week
#
# Summary: The world's best-performing tech stocks have bled an average $125 billion market cap per day for the past 20 days while crypto market cap has risen 11%.
#
#
#
# --------------------------------------------------
# NO. 11
# Stock Ticker: GOOG
# URL: https://www.benzinga.com/markets/equities/24/07/40057897/amd-partners-with-microsoft-meta-and-google-on-new-ai-accelerator-link-standard-to-challenge-nvi
# Published Time: 20240731T045033
#
# Title: AMD Partners With Microsoft, Meta, And Google On New AI Accelerator Link Standard To Challenge Nvidia's Dominance - Broadcom  ( NASDAQ:AVGO ) , Advanced Micro Devices  ( NASDAQ:AMD )
#
# Summary: Advanced Micro Devices Inc. AMD has teamed up with Microsoft Corp. MSFT, Meta Platforms Inc. META, and Alphabet Inc. GOOGL GOOG to develop a new AI accelerator standard, a move that could potentially disrupt the AI hardware market.
#
#
#
# --------------------------------------------------
# NO. 12
# Stock Ticker: GOOG
# URL: https://consent.google.com/m
# Published Time: 20240731T044831
#
# Title: Before you continue
#
# Summary: IPO listing today: Chetana Education shares list at 16% premium on NSE SME Business Standard ...
#
#
#
# --------------------------------------------------
# NO. 13
# Stock Ticker: GOOG
# URL: https://consent.google.com/m
# Published Time: 20240731T044416
#
# Title: Before you continue
#
# Summary: Torrent Power surges 19%, hits new high on robust June quarter earnings Business Standard ...
#
#
#
# --------------------------------------------------
# NO. 14
# Stock Ticker: GOOG
# URL: https://www.business-standard.com/technology/tech-news/microsoft-s-slow-cloud-growth-signals-ai-payoff-likely-to-take-longer-124073100251_1.html
# Published Time: 20240731T044356
#
# Title: Microsoft's slow cloud growth signals AI payoff likely to take longer
#
# Summary: Big technology companies have been pouring billions of dollars into data centers to capitalise on the generative AI boom ...
#
#
#
# --------------------------------------------------
# NO. 15
# Stock Ticker: GOOG
# URL: https://consent.google.com/m
# Published Time: 20240731T044356
#
# Title: Before you continue
#
# Summary: Microsoft's slow cloud growth signals AI payoff likely to take longer Business Standard ...
#
#
#
# --------------------------------------------------
# NO. 16
# Stock Ticker: GOOG
# URL: https://consent.google.com/m
# Published Time: 20240731T044049
#
# Title: Before you continue
#
# Summary: Capital gains tax changes may impact investment behaviour: Rashesh Shah Business Standard ...
#
#
#
# --------------------------------------------------
# NO. 17
# Stock Ticker: GOOG
# URL: https://consent.google.com/m
# Published Time: 20240731T043655
#
# Title: Before you continue
#
# Summary: About 8 in 10 Democrats satisfied with Harris after Biden's exit: Poll Business Standard ...
#
#
#
# --------------------------------------------------
# NO. 18
# Stock Ticker: GOOG
# URL: https://consent.google.com/m
# Published Time: 20240731T043430
#
# Title: Before you continue
#
# Summary: Taiwan detects 25 PLA aircraft, 10 naval vessels near its territory Business Standard ...
#
#
#
# --------------------------------------------------
# NO. 19
# Stock Ticker: GOOG
# URL: https://consent.google.com/m
# Published Time: 20240731T042915
#
# Title: Before you continue
#
# Summary: Biden, Lula press Venezuela to publish election tallies to end crisis Business Standard ...
#
#
#
# --------------------------------------------------
# NO. 20
# Stock Ticker: GOOG
# URL: https://consent.google.com/m
# Published Time: 20240731T042422
#
# Title: Before you continue
#
# Summary: Trump campaign launches new ads, calls Kamala Harris 'dangerously liberal' Business Standard ...
#
#
#
# --------------------------------------------------
# NO. 21
# Stock Ticker: GOOG
# URL: https://consent.google.com/m
# Published Time: 20240731T041344
#
# Title: Before you continue
#
# Summary: US election: Harris gains ground over Trump in 6 swing states, shows poll Business Standard ...
#
#
#
# --------------------------------------------------
# NO. 22
# Stock Ticker: GOOG
# URL: https://consent.google.com/m
# Published Time: 20240731T041329
#
# Title: Before you continue
#
# Summary: Bank holidays in August 2024: Here's the national and state-wise list Business Standard ...
#
#
#
# --------------------------------------------------
# NO. 23
# Stock Ticker: GOOG
# URL: https://consent.google.com/m
# Published Time: 20240731T041127
#
# Title: Before you continue
#
# Summary: All you need to know about Sebi proposals on index derivatives Business Standard ...
#
#
#
# --------------------------------------------------
# NO. 24
# Stock Ticker: GOOG
# URL: https://cointelegraph.com/news/friend-ai-necklace-wearable-companion-mixed-reaction-black-mirror
# Published Time: 20240731T040845
#
# Title: $99 AI necklace puts a 'friend' around your neck
#
# Summary: The tech entrepreneur who built a COVID-19 tracker as a teen in 2020 has now launched a new AI-powered necklace to combat loneliness. Some say it feels more like an episode of Black Mirror.
#
#
#
# --------------------------------------------------
# NO. 25
# Stock Ticker: GOOG
# URL: https://consent.google.com/m
# Published Time: 20240731T040700
#
# Title: Before you continue
#
# Summary: Market opens on a firm note. breadth strong Business Standard ...
#
#
#
# --------------------------------------------------
# NO. 26
# Stock Ticker: GOOG
# URL: https://www.fool.com/earnings/call-transcripts/2024/07/31/pinterest-pins-q2-2024-earnings-call-transcript/
# Published Time: 20240731T040027
#
# Title: Pinterest  ( PINS )  Q2 2024 Earnings Call Transcript
#
# Summary: PINS earnings call for the period ending June 30, 2024.
#
#
#
# --------------------------------------------------
# NO. 27
# Stock Ticker: GOOG
# URL: https://www.fool.com/earnings/call-transcripts/2024/07/31/skyworks-solutions-swks-q3-2024-earnings-call-tran/
# Published Time: 20240731T040021
#
# Title: Skyworks Solutions  ( SWKS )  Q3 2024 Earnings Call Transcript
#
# Summary: SWKS earnings call for the period ending June 30, 2024.
#
#
#
# --------------------------------------------------
# NO. 28
# Stock Ticker: GOOG
# URL: https://consent.google.com/m
# Published Time: 20240731T040000
#
# Title: Before you continue
#
# Summary: Black Box Ltd Slides 3.28% Business Standard ...
#
#
#
# --------------------------------------------------
# NO. 29
# Stock Ticker: GOOG
# URL: https://consent.google.com/m
# Published Time: 20240731T034955
#
# Title: Before you continue
#
# Summary: Hamas chief Ismail Haniyeh assassinated in 'Israeli raid' in Iran Business Standard ...
#
#
#
# --------------------------------------------------
# NO. 30
# Stock Ticker: GOOG
# URL: https://consent.google.com/m
# Published Time: 20240731T034832
#
# Title: Before you continue
#
# Summary: 'If you got something to say say it to my face': Harris as she slams Trump Business Standard ...
#
#
#
# --------------------------------------------------
# NO. 31
# Stock Ticker: GOOG
# URL: https://www.fool.com/earnings/call-transcripts/2024/07/30/carpartscom-prts-q2-2024-earnings-call-transcript/
# Published Time: 20240731T034527
#
# Title: CarParts.com  ( PRTS )  Q2 2024 Earnings Call Transcript
#
# Summary: PRTS earnings call for the period ending June 30, 2024.
#
#
#
# --------------------------------------------------
# NO. 32
# Stock Ticker: GOOG
# URL: https://www.fool.com/earnings/call-transcripts/2024/07/30/doubleverify-dv-q2-2024-earnings-call-transcript/
# Published Time: 20240731T034524
#
# Title: DoubleVerify  ( DV )  Q2 2024 Earnings Call Transcript
#
# Summary: DV earnings call for the period ending June 30, 2024.
#
#
#
# --------------------------------------------------
# NO. 33
# Stock Ticker: GOOG
# URL: https://consent.google.com/m
# Published Time: 20240731T033736
#
# Title: Before you continue
#
# Summary: Airbus faces criminal probe in Britain over potential export control breach Business Standard ...
#
#
#
# --------------------------------------------------
# NO. 34
# Stock Ticker: GOOG
# URL: https://consent.google.com/m
# Published Time: 20240731T033537
#
# Title: Before you continue
#
# Summary: LIVE news: 156 dead in Wayanad landslides, many still trapped as rescue ops continue Business Standard ...
#
#
#
# --------------------------------------------------
# NO. 35
# Stock Ticker: GOOG
# URL: https://consent.google.com/m
# Published Time: 20240731T032951
#
# Title: Before you continue
#
# Summary: How to trade Gold ahead of US Fed outcome today? Check key levels here Business Standard ...
#
#
#
# --------------------------------------------------
# NO. 36
# Stock Ticker: GOOG
# URL: https://consent.google.com/m
# Published Time: 20240731T032804
#
# Title: Before you continue
#
# Summary: Paris Olympics 2024: India schedule on July 31, live time ( IST ) , streaming Business Standard ...
#
#
#
# --------------------------------------------------
# NO. 37
# Stock Ticker: GOOG
# URL: https://consent.google.com/m
# Published Time: 20240731T032519
#
# Title: Before you continue
#
# Summary: Google autocomplete results of Trump assassination bid stems questions Business Standard ...
#
#
#
# --------------------------------------------------
# NO. 38
# Stock Ticker: GOOG
# URL: https://consent.google.com/m
# Published Time: 20240731T031637
#
# Title: Before you continue
#
# Summary: China's factory activity shrinks in July, service sector grow more slowly Business Standard ...
#
#
#
# --------------------------------------------------
# NO. 39
# Stock Ticker: GOOG
# URL: https://consent.google.com/m
# Published Time: 20240731T031543
#
# Title: Before you continue
#
# Summary: Trading strategy, July 31: Silver may consolidate gains before Fed outcome Business Standard ...
#
#
#
# --------------------------------------------------
# NO. 40
# Stock Ticker: GOOG
# URL: https://consent.google.com/m
# Published Time: 20240731T031450
#
# Title: Before you continue
#
# Summary: US election: Harris to hold Philadelphia rally with VP pick on Tuesday Business Standard ...
#
#
#
# --------------------------------------------------
# NO. 41
# Stock Ticker: GOOG
# URL: https://consent.google.com/m
# Published Time: 20240731T030800
#
# Title: Before you continue
#
# Summary: Indices likely to open higher on Asian gains Business Standard ...
#
#
#
# --------------------------------------------------
# NO. 42
# Stock Ticker: GOOG
# URL: https://consent.google.com/m
# Published Time: 20240731T030731
#
# Title: Before you continue
#
# Summary: Tata Motors Q1 Preview: JLR, Indian CV sales may fuel revenue growth Business Standard ...
#
#
#
# --------------------------------------------------
# NO. 43
# Stock Ticker: GOOG
# URL: https://consent.google.com/m
# Published Time: 20240731T030236
#
# Title: Before you continue
#
# Summary: Asian stocks steady, yen firm ahead of Bank of Japan's policy decision Business Standard ...
#
#
#
# --------------------------------------------------
# NO. 44
# Stock Ticker: GOOG
# URL: https://consent.google.com/m
# Published Time: 20240731T025744
#
# Title: Before you continue
#
# Summary: Samsung flags strong AI demand as Q2 profit soars on higher chip prices Business Standard ...
#
#
#
# --------------------------------------------------
# NO. 45
# Stock Ticker: GOOG
# URL: https://consent.google.com/m
# Published Time: 20240731T025737
#
# Title: Before you continue
#
# Summary: Samsung flags strong AI demand as Q2 profit soars on higher chip prices Business Standard ...
#
#
#
# --------------------------------------------------
# NO. 46
# Stock Ticker: GOOG
# URL: https://consent.google.com/m
# Published Time: 20240731T024813
#
# Title: Before you continue
#
# Summary: Stocks to Watch Today, July 31: Vedanta, GAIL,Coal India, BHEL, Adani Power Business Standard ...
#
#
#
# --------------------------------------------------
# NO. 47
# Stock Ticker: GOOG
# URL: https://consent.google.com/m
# Published Time: 20240731T024153
#
# Title: Before you continue
#
# Summary: Akasa eyes flights to Asia tourist hotspots as overseas travel demand rises Business Standard ...
#
#
#
# --------------------------------------------------
# NO. 48
# Stock Ticker: GOOG
# URL: https://consent.google.com/m
# Published Time: 20240731T022954
#
# Title: Before you continue
#
# Summary: Here's why Honda is losing the electric two-wheeler race in Indian market Business Standard ...
#
#
#
# --------------------------------------------------
# NO. 49
# Stock Ticker: GOOG
# URL: https://consent.google.com/m
# Published Time: 20240731T022828
#
# Title: Before you continue
#
# Summary: Foreign lawmakers discuss Chinese actions around Taiwan, costs of conflict Business Standard ...
#
#
#
# --------------------------------------------------
# NO. 50
# Stock Ticker: GOOG
# URL: https://consent.google.com/m
# Published Time: 20240731T022446
#
# Title: Before you continue
#
# Summary: Death toll climbs to 143 in Wayanad landslide tragedy, rescue op underway Business Standard ...

# %%
# !mkdir stock_news
import os

today = datetime.datetime.now()
today_str = today.strftime("%Y-%m-%d")

dir_path = './stock_news'
file_path = f"{dir_path}/stockNews_{today_str}_{group_index}.txt"
file_name = os.path.basename(file_path)

with open(file_path, 'w') as file:
    file.write(formatted_news)
print(f"News has been saved to {dir_path}, filename: {file_name}")
# Out:
# News has been saved to ./stock_news, filename: stockNews_2024-07-31_1.txt

# %%
from google.oauth2 import service_account
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

# google api certification
SERVICE_ACCOUNT_FILE = "./news-project.json"
SCOPES = ["https://www.googleapis.com/auth/drive", "https://www.googleapis.com/auth/documents"]

credentials = service_account.Credentials.from_service_account_file(SERVICE_ACCOUNT_FILE, scopes=SCOPES)

# 创建 Google Drive 和 Google Docs 服务
drive_service = build('drive', 'v3', credentials=credentials)
docs_service = build('docs', 'v1', credentials=credentials)

# 指定资料夹 ID 和文件名称
folder_id = "googleDrive_folder_id"
file_name = f"stockNews_{today_str}_{group_index}"


def create_google_docs_file(name, folder_id):
    file_metadata = {
        'name': name,
        'mimeType': 'application/vnd.google-apps.document',
        'parents': [folder_id]
    }
    try:
        file = drive_service.files().create(body=file_metadata, fields="id").execute()
        print(f'Created file with ID: {file.get("id")}')
        return file.get('id')
    except HttpError as error:
        print(f'An error occurred: {error}')
        return None

def write_to_google_docs(doc_id, content):
    doc_metadata = [
        {
            'insertText': {
                'location': {
                    'index': 1
                },
                'text': content
            }
        }
    ]
    try:
        result = docs_service.documents().batchUpdate(documentId=doc_id, body={'requests': doc_metadata}).execute()
        print(f'Updated document with ID: {doc_id}')
    except HttpError as error:
        print(f'An error occurred: {error}')

doc_id = create_google_docs_file(file_name, folder_id)
if doc_id:
    write_to_google_docs(doc_id, formatted_news)

# %%
list_formatted_news = formatted_news.split("****************************************")[1:]
len(list_formatted_news)
# Out:
# 7

# %%
import ollama
import os
from tqdm import tqdm

ai_report_path = f"./ai_report/{today_str}_{group_index}.txt"

ai_num = 0

for oneTicker_content in tqdm(list_formatted_news, desc="Analyzing ticker news...", unit='B', unit_scale=True, unit_divisor=1024):
    
    ticker_prompt = f"""
你作為一個金融分析師和金融媒體專家，
請針對下面Stock Ticker所列新聞內容分別產出重點英文及繁體中文新聞摘要內容，
並在最下面列出所有新聞編號和URL，
如果Stock Ticker今天總共有0則新聞，沒有實際新聞內容，請直接回覆**今日沒有更新{{Stock Ticker}}新聞**，
請務必一開始就列出這篇摘要{{Stock Ticker}}為何，以及在最後列出我給你的原始新聞連結，

**產出格式如下**
[Stock Ticker] 新聞重點摘要如下:
英文摘要
1.第1項重點內容
2.第2項重點內容
......依序列出
參考新聞URL

中文摘要
1.第1項重點內容
2.第2項重點內容
......依序列出
參考新聞URL

所有原始新聞連結
1.URL1
2.URL2
......依序列出

**相關新聞內容如下**
{oneTicker_content}
"""
    
    response = ollama.chat(model='llama3.1:latest', messages=[
      {
        'role': 'user',
        'content': ticker_prompt,
      }], options={'temperature': 0.2, 'max_tokens': 500})
     
#     translate_prompt = f"""
# 請將下面英文摘要內容翻譯成繁體中文，
# 並只要提供給我繁體中文翻譯內容就好，
# 不要有其他內容

# **格式如下**
# [Stock Ticker] English Summary:
# translation content here
    
# 需要翻譯內容如下:
# {response['message']['content']}
# """
  
#     translate = ollama.chat(model='llama3.1:latest', messages=[
#       {
#         'role': 'user',
#         'content': translate_prompt,
#       },
#     ])


    result = f"""
\n
{response['message']['content']}\n
--------------------------------------------------
"""

#     result = f"""
# --------------------------------------------------
# 英文摘要\n
# {response['message']['content']}

# 中文摘要\n
# {translate['message']['content']}
# """
    print(str(ai_num) + "\n" + result)
    
    if os.path.exists(ai_report_path):
        with open(ai_report_path, "a") as file:
            file.write(result)
    else:
        with open(ai_report_path, "w") as file:
            file.write(result)


    ai_num += 1
# Out:
# Analyzing ticker news...:  14%|█████▌                                 | 1.00/7.00 [00:05<00:30, 5.13s/B]
# 0
#
#
#
# **SNAP 新聞重點摘要如下:**
# 英文摘要
# **今日沒有更新{SNAP}新聞**
#
# 中文摘要
# **今日沒有更新{SNAP}新聞**
#
# 所有原始新聞連結
# 1.
# 2.
# ......依序列出
#
# --------------------------------------------------
# Analyzing ticker news...:  29%|███████████▏                           | 2.00/7.00 [00:11<00:28, 5.73s/B]
# 1
#
#
#
# **Stock Ticker: SNOW**
# 新聞重點摘要如下:
# 英文摘要
# 1. Whales with a lot of money to spend have taken a noticeably bearish stance on Snowflake.
# 2. Looking at options history for Snowflake SNOW we detected 40 trades.
#
# 中文摘要
# 1. 大量資金的鯊魚已經對Snowflake表現出明顯的悲觀態度。
# 2. 對Snowflake選項歷史進行了檢視，我們發現了40個交易。
#
# 所有原始新聞連結:
# 1. https://www.benzinga.com/insights/options/24/07/40048837/what-the-options-market-tells-us-about-snowflake
#
# --------------------------------------------------
# Analyzing ticker news...:  43%|████████████████▋                      | 3.00/7.00 [00:34<00:54, 13.5s/B]
# 2
#
#
#
# Here are the 31 news articles about Tesla (TSLA) from July 30, 2024:
#
# 1. **How A Phone Call With Vanguard Founder Jack Bogle Transformed Bob Pisani's Perspective And Revolutionized Investing**
# 	* URL: https://www.benzinga.com/markets/equities/24/07/40031326/
# 	* Summary: Bob Pisani shares how a phone call with Jack Bogle transformed his perspective on investing.
# 2. **Former Tesla Exec Says Biden Administration's Treatment Of EV Giant Was 'Pretty Fair' Despite Musk's Allegations**
# 	* URL: https://www.benzinga.com/news/24/07/40031325/
# 	* Summary: Former Tesla executive Rohan Patel says the Biden administration treated Tesla fairly.
# 3. **Nvidia, Alphabet, and Microsoft Are Sinking This Month. Here's a Safer Way to Invest in Artificial Intelligence Stocks**
# 	* URL: https://www.fool.com/investing/2024/07/30/nvidia-alphabet-microsoft-month-safer-in-ai-stocks/
# 	* Summary: Investors can avoid picking winners and losers with this simple AI investment strategy.
# 4. **Tesla Replaces Ford As Morgan Stanley's 'Top Pick' As Brokerage Sees Potential In EV Giant's Energy And Service Segments**
# 	* URL: https://www.benzinga.com/analyst-ratings/analyst-color/24/07/40030402/
# 	* Summary: Tesla replaces Ford as Morgan Stanley's top pick in the US auto industry.
# 5. **US Stocks Close Mixed Ahead Of Big Earnings, Fed Decision: Investor Optimism Improves Further**
# 	* URL: https://www.benzinga.com/news/earnings/24/07/40029782/
# 	* Summary: US stocks close mixed ahead of earnings and the Federal Reserve's policy decision.
# 6. **Tesla CEO Elon Musk Turns Down Possibility Of Model S Plaid Plus Variant, Upcoming Roadster Set To Fill That Gap Instead**
# 	* URL: https://www.benzinga.com/news/24/07/40028740/
# 	* Summary: Tesla CEO Elon Musk denies a future possibility of the Model S Plaid+ variant.
#
# --------------------------------------------------
# Analyzing ticker news...:  57%|██████████████████████▎                | 4.00/7.00 [00:40<00:32, 10.8s/B]
# 3
#
#
#
# **Stock Ticker: U**
# 新聞重點摘要如下:
# 英文摘要
# 1. Unity Software Inc. (U) closed the most recent trading day at $16.20.
# 2. The stock moved -0.95% from the previous trading session.
#
# 中文摘要
# 1. Unity Software Inc. (U) 最近交易日收盤價為$16.20。
# 2. 该股票在上一交易日的市場波動中下跌了-0.95%。
#
# 所有原始新聞連結:
# 1. https://www.zacks.com/stock/news/2312387/unity-software-inc-u-dips-more-than-broader-market-what-you-should-know
#
# --------------------------------------------------
# Analyzing ticker news...:  71%|███████████████████████████▊           | 5.00/7.00 [00:42<00:15, 7.62s/B]
# 4
#
#
#
# WOLF 新聞重點摘要如下:
# 英文摘要
# **今日沒有更新WOLF新聞**
#
# 中文摘要
# **今日沒有更新WOLF新聞**
#
# 所有原始新聞連結
# 1.
# 2.
# ......依序列出
#
# --------------------------------------------------
# Analyzing ticker news...:  86%|█████████████████████████████████▍     | 6.00/7.00 [00:48<00:07, 7.03s/B]
# 5
#
#
#
# **Stock Ticker ACN新聞重點摘要如下：**
# 英文摘要
# 1. Microsoft's Q4 2024 earnings report shows a revenue increase of 12% year-over-year.
# 2. The company's operating income grew by 15% compared to the same period last year.
#
# 中文摘要
# 1.微軟Q4 2024財報顯示收入同比增長12%。
# 2.公司的營業收益較去年同期增長15%。
#
# 所有原始新聞連結：
# 1. https://www.fool.com/earnings/call-transcripts/2024/07/30/microsoft-msft-q4-2024-earnings-call-transcript/
#
# --------------------------------------------------
# Analyzing ticker news...: 100%|███████████████████████████████████████| 7.00/7.00 [01:06<00:00, 9.54s/B]
# 6
#
#
#
# The articles provided are a list of news headlines from Business Standard on July 31, 2024. Here's a summary of the key points:
#
# 1. **Landslide in Wayanad**: The death toll has risen to 156 with many still trapped as rescue operations continue.
# 2. **Gold Trading**: Ahead of the US Fed outcome, check key levels for trading gold.
# 3. **Paris Olympics 2024**: India's schedule on July 31 will be live-streamed (IST).
# 4. **Google Autocomplete**: Results of Trump assassination bid raise questions.
# 5. **China's Factory Activity**: Shrinks in July with service sector growing more slowly.
# 6. **Silver Trading**: May consolidate gains before the Fed outcome.
# 7. **US Election**: Harris to hold a rally in Philadelphia on Tuesday with VP pick.
# 8. **Indices Opening**: Likely to open higher on Asian gains.
# 9. **Tata Motors Q1 Preview**: JLR and Indian CV sales may fuel revenue growth.
# 10. **Asian Stocks**: Steady, yen firm ahead of Bank of Japan's policy decision.
# 11. **Samsung Q2 Profit**: Soars on higher chip prices with strong AI demand.
# 12. **Stocks to Watch**: Vedanta, GAIL, Coal India, BHEL, and Adani Power are among the stocks to watch today.
# 13. **Akasa Air**: Eyes flights to Asia tourist hotspots as overseas travel demand rises.
# 14. **Honda Electric Two-Wheeler**: Losing the electric two-wheeler race in the Indian market.
# 15. **Chinese Actions around Taiwan**: Foreign lawmakers discuss costs of conflict.
#
# Please note that these articles are from July 31, 2024, and may not be relevant or up-to-date as of your current time.
#
# --------------------------------------------------

# %%
import telebot

bot_token = 'telebot_token'
chat_id = 'telegram_chat_id'

bot = telebot.TeleBot(bot_token)

with open(f"./ai_report/{today_str}_{group_index}.txt", "r") as file:
    news_message = file.read()

list_news_message = news_message.split("--------------------------------------------------")[:-1]

bot_num = 0
for one_message in list_news_message:
    one_message = f"||{today_str} 新聞摘要||" + one_message
    if (len(one_message)<=4096):
        bot.send_message(chat_id, one_message)
    bot_num += 1

with open(f"./stock_news/stockNews_{today_str}_{group_index}.txt", 'rb') as file:
    bot.send_document(chat_id, file)
